# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.ticker as ticker

# %%
# %matplotlib widget

# %% [markdown]
# # Basics

# %% [markdown]
# lists, tuples, numpy arrays

# %% [markdown]
# zeros, ones, random, empty etc.

# %% [markdown]
# indexing

# %% [markdown]
# # Intro

# %% [markdown]
# What is a vector?

# %%
v1 = np.array([5, 7])

# %%
fig, ax = plt.subplots(figsize=(3, 3))

ax.quiver([0], [0], [v1[0]], [v1[1]], units="xy", angles="xy", scale_units="xy", scale=1, zorder=2)

ax.grid(visible=True, zorder=1)
ax.set_xlim(0, 8)
ax.set_ylim(0, 8)
ax.set_xticks(np.arange(9))
ax.set_yticks(np.arange(9));
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Unit vectors

# %% [markdown]
# Unit and basis vectors

# %%
i = np.array([1., 0.])
j = np.array([0., 1.])

# %%
fig, ax = plt.subplots(figsize=(3, 3))

for v in (i, j):
    ax.quiver([0], [0], [v[0]], [v[1]], units="xy", angles="xy", scale_units="xy", scale=1, zorder=2)
ax.scatter([0], [0], c="k", zorder=2)

ax.grid(visible=True, zorder=1)
ax.set_xlim(-3, 3)
ax.set_ylim(-3, 3)
ax.set_xticks(np.arange(-3, 4))
ax.set_yticks(np.arange(-3, 4));
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
v1 = 5 * i + 7 * j

# %%
v1
# Out:
# array([5., 7.])

# %%
fig, ax = plt.subplots(figsize=(3, 3))

ax.quiver([0], [0], [v1[0]], [v1[1]], units="xy", angles="xy", scale_units="xy", scale=1, zorder=2)

ax.grid(visible=True, zorder=1)
ax.set_xlim(0, 8)
ax.set_ylim(0, 8)
ax.set_xticks(np.arange(9))
ax.set_yticks(np.arange(9));
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Vectors have a magnitude (length)

# %%
# Pythagoras theorem

# %%
length = np.sqrt(v1[0] ** 2 + v1[1] ** 2)
print(length)
# Out:
# 8.602325267042627

# %%
length = np.linalg.norm(v1)
print(length)
# Out:
# 8.602325267042627

# %%
v_normed = v1 / length
print(v_normed)
# Out:
# [0.58123819 0.81373347]

# %% [markdown]
# # Dot product

# %%
v2 = np.array([12, -3])

# %%
fig, ax = plt.subplots(figsize=(3, 3))
for v in (v1, v2):
    ax.quiver([0], [0], [v[0]], [v[1]], units="xy", angles="xy", scale_units="xy", scale=1, zorder=2)
ax.scatter([0], [0], c="k", zorder=2)

ax.grid(visible=True, zorder=1)
ax.set_xlim(-5, 15)
ax.set_ylim(-5, 15)
ax.set_xticks(np.arange(-5, 15))
ax.set_yticks(np.arange(-5, 15));
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Adding vectors

# %%
v3 = v1 + v2
print(v3)
# Out:
# [17.  4.]

# %%
fig, ax = plt.subplots(figsize=(3, 3))

ax.plot([0, v1[0]], [0, v1[1]], c="b")
ax.plot([v1[0], v3[0]], [v1[1], v3[1]], c="r")
ax.quiver([0], [0], [v3[0]], [v3[1]], units="xy", angles="xy", scale_units="xy", scale=1, zorder=2)
ax.scatter([0], [0], c="k", zorder=2)

ax.grid(visible=True, zorder=1)
ax.set_xlim(-5, 20)
ax.set_ylim(-5, 20)
ax.xaxis.set_major_locator(ticker.MultipleLocator(base=5))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(base=1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(base=5))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(base=1))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Multiplying vectors (dot product)

# %%
# Multiply xs and ys
product = v1 * v2
print(product)
# Out:
# [ 60. -21.]

# %%
# then sum
np.sum(product)
# Out:
# 39.0

# %%
# Dot product
dot = np.dot(v1, v2)
print(dot)
# Out:
# 39.0

# %% [markdown]
# ### Why use a dot product?

# %%
print(v1, v2)
# Out:
# [5. 7.] [12 -3]

# %%
v1_normed = v1 / np.linalg.norm(v1)
v2_normed = v2 / np.linalg.norm(v2)

# %%
print(v1_normed, v2_normed)
# Out:
# [0.58123819 0.81373347] [ 0.9701425  -0.24253563]

# %%
fig, ax = plt.subplots(figsize=(3, 3))

ax.quiver([0], [0], [v1_normed[0]], [v1_normed[1]], units="xy", angles="xy", scale_units="xy", scale=1, zorder=2)
ax.quiver([0], [0], [v2_normed[0]], [v2_normed[1]], units="xy", angles="xy", scale_units="xy", scale=1, zorder=2)
ax.scatter([0], [0], c="k", zorder=2)

ax.grid(visible=True, zorder=1)
ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
ax.xaxis.set_major_locator(ticker.MultipleLocator(base=.2))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(base=.1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(base=.2))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(base=.1))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
normed_dot = np.dot(v1_normed, v2_normed)
normed_dot
# Out:
# 0.3665245183824907

# %%
v1_scaled = v1_normed * normed_dot
v2_scaled = v2_normed * normed_dot

# %%
kwargs = dict(units="xy", angles="xy", scale_units="xy", scale=1, zorder=2)

# %%
fig, ax = plt.subplots(figsize=(3, 3))

ax.quiver([0], [0], [v1_normed[0]], [v1_normed[1]], **kwargs)
ax.quiver([0], [0], [v2_normed[0]], [v2_normed[1]], **kwargs)

ax.quiver([0], [0], [v1_scaled[0]], [v1_scaled[1]], color="r", **kwargs)
ax.quiver([0], [0], [v2_scaled[0]], [v2_scaled[1]], color="b", **kwargs)

ax.plot([v1_scaled[0], v2_normed[0]], [v1_scaled[1], v2_normed[1]], linestyle="--", c="r")
ax.plot([v2_scaled[0], v1_normed[0]], [v2_scaled[1], v1_normed[1]], linestyle="--", c="b")

ax.scatter([0], [0], c="k", zorder=2)

ax.grid(visible=True, zorder=1)
ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
ax.xaxis.set_major_locator(ticker.MultipleLocator(base=.2))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(base=.1))
ax.yaxis.set_major_locator(ticker.MultipleLocator(base=.2))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(base=.1))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# What does a dot product of zero mean?
